# %%
import cProfile
# %load_ext line_profiler

# %%
import os
os.environ['NUMBA_DISABLE_JIT'] = '1'

# %%
from tardis.io.config_reader import Configuration
from tardis.io.atom_data.base import AtomData
from tardis.simulation import Simulation
from tardis import run_tardis
from tardis.io.atom_data.util import download_atom_data
download_atom_data('kurucz_cd23_chianti_H_He')
# Out:
# [tardis.io.atom_data.atom_web_download][INFO   ]  Downloading atomic data from https://media.githubusercontent.com/media/tardis-sn/tardis-refdata/master/atom_data/kurucz_cd23_chianti_H_He.h5 to /home/kevin/Downloads/tardis-data/kurucz_cd23_chianti_H_He.h5 (atom_web_download.py:46)

# %%
tardis_config = Configuration.from_yaml('tardis_example.yml')
sim = Simulation.from_config(tardis_config)
# Out:
# [tardis.plasma.standard_plasmas][INFO   ]  Reading Atomic Data from kurucz_cd23_chianti_H_He.h5 (standard_plasmas.py:91)
# [tardis.io.atom_data.util][INFO   ]  Atom Data kurucz_cd23_chianti_H_He.h5 not found in local path. Exists in TARDIS Data repo /home/kevin/Downloads/tardis-data/kurucz_cd23_chianti_H_He.h5 (util.py:34)
# [tardis.io.atom_data.base][INFO   ]  Read Atom Data with UUID=6f7b09e887a311e7a06b246e96350010 and MD5=864f1753714343c41f99cb065710cace. (base.py:179)
# [tardis.io.atom_data.base][INFO   ]  Non provided atomic data: synpp_refs, photoionization_data, yg_data, two_photon_data (base.py:183)

# %%
cProfile.run('sim.run()', 'cprofile_tardis_full_run.txt')
# Out:
# [tardis.simulation.base][INFO   ]  Starting iteration 1/20 (base.py:323)
# [py.warnings         ][WARNING]  /home/kevin/miniconda3/envs/tardis/lib/python3.7/site-packages/astropy/units/equivalencies.py:124: RuntimeWarning: divide by zero encountered in double_scalars
#   (si.m, si.Hz, lambda x: _si.c.value / x),
#  (warnings.py:110)
# Running post-merge numba montecarlo (with C close lines)!
# [tardis.simulation.base][INFO   ]  Luminosity emitted = 7.94275e+42 erg / s Luminosity absorbed = 2.65805e+42 erg / s Luminosity requested = 1.05928e+43 erg / s (base.py:438)
# [tardis.simulation.base][INFO   ]  Plasma stratification:
# 	             t_rad    next_t_rad         w    next_w
# 	Shell
# 	0      9926.501965  10134.733717  0.400392  0.508204
# 	5      9852.611678  10222.890845  0.211205  0.197026
# 	10     9779.813302  10144.463169  0.142695  0.117179
# 	15     9708.082813   9873.477846  0.104556  0.086941
#
#  (base.py:433)
# ...

# %%
import pstats
from pstats import SortKey
p = pstats.Stats('cprofile_tardis_full_run.txt')

# %%
p.sort_stats(SortKey.CALLS).print_stats('/home/kevin/tardis/', 100)
# Out:
# Mon May 31 20:09:02 2021    cprofile_tardis_full_run.txt
#
#          5116263772 function calls (5116238789 primitive calls) in 5996.375 seconds
#
#    Ordered by: call count
#    List reduced from 1564 to 126 due to restriction <'/home/kevin/tardis/'>
#    List reduced from 126 to 100 due to restriction <100>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
# 808226878  933.415    0.000  933.415    0.000 /home/kevin/tardis/tardis/montecarlo/montecarlo_numba/calculate_distances.py:63(calculate_distance_line)
# 795477943  756.372    0.000  832.263    0.000 /home/kevin/tardis/tardis/montecarlo/montecarlo_numba/r_packet.py:324(test_for_close_line)
# 252904768  118.533    0.000  118.533    0.000 /home/kevin/tardis/tardis/montecarlo/montecarlo_numba/opacities.py:12(calculate_tau_electron)
# 212598199  103.005    0.000  103.005    0.000 /home/kevin/tardis/tardis/montecarlo/montecarlo_numba/calculate_distances.py:137(calculate_distance_electron)
# ...

# %%
p.sort_stats(SortKey.TIME).print_stats('/home/kevin/tardis/', 100)
# Out:
# Mon May 31 20:09:02 2021    cprofile_tardis_full_run.txt
#
#          5116263772 function calls (5116238789 primitive calls) in 5996.375 seconds
#
#    Ordered by: internal time
#    List reduced from 1564 to 126 due to restriction <'/home/kevin/tardis/'>
#    List reduced from 126 to 100 due to restriction <100>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#  40306569 1310.387    0.000 2741.735    0.000 /home/kevin/tardis/tardis/montecarlo/montecarlo_numba/vpacket.py:69(trace_vpacket_within_shell)
#  16196415  947.517    0.000 2436.450    0.000 /home/kevin/tardis/tardis/montecarlo/montecarlo_numba/r_packet.py:95(trace_packet)
# 808226878  933.415    0.000  933.415    0.000 /home/kevin/tardis/tardis/montecarlo/montecarlo_numba/calculate_distances.py:63(calculate_distance_line)
# 795477943  756.372    0.000  832.263    0.000 /home/kevin/tardis/tardis/montecarlo/montecarlo_numba/r_packet.py:324(test_for_close_line)
# ...

# %%
p.sort_stats(SortKey.CALLS).print_stats('montecarlo_numba/*', 100)
# Out:
# Mon May 31 20:09:02 2021    cprofile_tardis_full_run.txt
#
#          5116263772 function calls (5116238789 primitive calls) in 5996.375 seconds
#
#    Ordered by: call count
#    List reduced from 1564 to 38 due to restriction <'montecarlo_numba/*'>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
# 808226878  933.415    0.000  933.415    0.000 /home/kevin/tardis/tardis/montecarlo/montecarlo_numba/calculate_distances.py:63(calculate_distance_line)
# 795477943  756.372    0.000  832.263    0.000 /home/kevin/tardis/tardis/montecarlo/montecarlo_numba/r_packet.py:324(test_for_close_line)
# 252904768  118.533    0.000  118.533    0.000 /home/kevin/tardis/tardis/montecarlo/montecarlo_numba/opacities.py:12(calculate_tau_electron)
# 212598199  103.005    0.000  103.005    0.000 /home/kevin/tardis/tardis/montecarlo/montecarlo_numba/calculate_distances.py:137(calculate_distance_electron)
# ...

# %%
p.sort_stats(SortKey.TIME).print_stats('montecarlo_numba/base.py')
# Out:
# Mon May 31 20:09:02 2021    cprofile_tardis_full_run.txt
#
#          5116263772 function calls (5116238789 primitive calls) in 5996.375 seconds
#
#    Ordered by: internal time
#    List reduced from 1564 to 2 due to restriction <'montecarlo_numba/base.py'>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        20   35.660    1.783 5884.754  294.238 /home/kevin/tardis/tardis/montecarlo/montecarlo_numba/base.py:104(montecarlo_main_loop)
#        20    0.001    0.000 5884.802  294.240 /home/kevin/tardis/tardis/montecarlo/montecarlo_numba/base.py:30(montecarlo_radial1d)

# %%
p.sort_stats(SortKey.TIME).print_stats('single_packet_loop.py')
# Out:
# Mon May 31 20:09:02 2021    cprofile_tardis_full_run.txt
#
#          5116263772 function calls (5116238789 primitive calls) in 5996.375 seconds
#
#    Ordered by: internal time
#    List reduced from 1564 to 2 due to restriction <'single_packet_loop.py'>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    860000   79.694    0.000 5801.623    0.007 /home/kevin/tardis/tardis/montecarlo/montecarlo_numba/single_packet_loop.py:38(single_packet_loop)
#    860000    1.769    0.000    3.868    0.000 /home/kevin/tardis/tardis/montecarlo/montecarlo_numba/single_packet_loop.py:136(set_packet_props_partial_relativity)

# %%
p.sort_stats(SortKey.TIME).print_stats('calculate_distances.py')
# Out:
# Mon May 31 20:09:02 2021    cprofile_tardis_full_run.txt
#
#          5116263772 function calls (5116238789 primitive calls) in 5996.375 seconds
#
#    Ordered by: internal time
#    List reduced from 1564 to 3 due to restriction <'calculate_distances.py'>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
# 808226878  933.415    0.000  933.415    0.000 /home/kevin/tardis/tardis/montecarlo/montecarlo_numba/calculate_distances.py:63(calculate_distance_line)
#  56502984  117.088    0.000  126.545    0.000 /home/kevin/tardis/tardis/montecarlo/montecarlo_numba/calculate_distances.py:19(calculate_distance_boundary)
# 212598199  103.005    0.000  103.005    0.000 /home/kevin/tardis/tardis/montecarlo/montecarlo_numba/calculate_distances.py:137(calculate_distance_electron)
