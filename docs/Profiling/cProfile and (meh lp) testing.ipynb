# %%
from tardis import run_tardis
from tardis.io.atom_data.util import download_atom_data

# %%
# the data is automatically downloaded
download_atom_data('kurucz_cd23_chianti_H_He')
# Out:
# [tardis.io.atom_data.atom_web_download][INFO   ]  Downloading atomic data from https://media.githubusercontent.com/media/tardis-sn/tardis-refdata/master/atom_data/kurucz_cd23_chianti_H_He.h5 to /home/kevin/Downloads/tardis-data/kurucz_cd23_chianti_H_He.h5 (atom_web_download.py:46)

# %%
#TARDIS now uses the data in the data repo
#!curl -O https://raw.githubusercontent.com/tardis-sn/tardis/master/docs/tardis_example.yml
import cProfile
import profile

# %%
cProfile.run("run_tardis('tardis_example.yml')", 'run_data.txt')
# Out:
# [tardis.plasma.standard_plasmas][INFO   ]  Reading Atomic Data from kurucz_cd23_chianti_H_He.h5 (standard_plasmas.py:91)
# [tardis.io.atom_data.util][INFO   ]  Atom Data kurucz_cd23_chianti_H_He.h5 not found in local path. Exists in TARDIS Data repo /home/kevin/Downloads/tardis-data/kurucz_cd23_chianti_H_He.h5 (util.py:34)
# [tardis.io.atom_data.base][INFO   ]  Read Atom Data with UUID=6f7b09e887a311e7a06b246e96350010 and MD5=864f1753714343c41f99cb065710cace. (base.py:179)
# [tardis.io.atom_data.base][INFO   ]  Non provided atomic data: synpp_refs, photoionization_data, yg_data, two_photon_data (base.py:183)
# [tardis.simulation.base][INFO   ]  Starting iteration 1/20 (base.py:323)
# [py.warnings         ][WARNING]  /home/kevin/miniconda3/envs/tardis/lib/python3.7/site-packages/astropy/units/equivalencies.py:124: RuntimeWarning: divide by zero encountered in double_scalars
#   (si.m, si.Hz, lambda x: _si.c.value / x),
#  (warnings.py:110)
# ...

# %%
import pstats
from pstats import SortKey
p = pstats.Stats('run_data.txt')

# %%
p.sort_stats(SortKey.CUMULATIVE).print_stats(10)
# Out:
# Tue May 25 09:18:36 2021    run_data.txt
#
#          27345037 function calls (25209487 primitive calls) in 28.006 seconds
#
#    Ordered by: cumulative time
#    List reduced from 10557 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    1577/1    0.005    0.000   28.015   28.015 {built-in method builtins.exec}
#         1    0.000    0.000   28.015   28.015 <string>:1(<module>)
#         1    0.000    0.000   28.015   28.015 /home/kevin/tardis/tardis/base.py:4(run_tardis)
#         1    0.000    0.000   25.109   25.109 /home/kevin/tardis/tardis/simulation/base.py:347(run)
#        20    0.001    0.000   23.951    1.198 /home/kevin/tardis/tardis/simulation/base.py:321(iterate)
#        20    0.004    0.000   23.779    1.189 /home/kevin/tardis/tardis/montecarlo/base.py:257(run)
#        20    0.001    0.000   23.409    1.170 /home/kevin/tardis/tardis/montecarlo/montecarlo_numba/base.py:30(montecarlo_radial1d)
# ...

# %%
p.sort_stats(SortKey.TIME).print_stats(10)
# Out:
# Tue May 25 09:18:36 2021    run_data.txt
#
#          27345037 function calls (25209487 primitive calls) in 28.006 seconds
#
#    Ordered by: internal time
#    List reduced from 10557 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        20   11.930    0.597   11.969    0.598 /home/kevin/tardis/tardis/montecarlo/montecarlo_numba/base.py:104(montecarlo_main_loop)
#     53786    3.838    0.000    4.572    0.000 /home/kevin/miniconda3/envs/tardis/lib/python3.7/site-packages/llvmlite/binding/ffi.py:149(__call__)
# 734412/1078    0.488    0.000    1.137    0.001 /home/kevin/miniconda3/envs/tardis/lib/python3.7/copy.py:132(deepcopy)
#        43    0.455    0.011    0.775    0.018 {method 'get_indexer' of 'pandas._libs.index.BaseMultiIndexCodesEngine' objects}
# 694266/122891    0.416    0.000    0.592    0.000 /home/kevin/miniconda3/envs/tardis/lib/python3.7/site-packages/numba/core/ir.py:313(_rec_list_vars)
# ...

# %%
p.sort_stats(SortKey.TIME).print_stats('montecarlo_numba/r_packet.py')
# Out:
# Tue May 25 09:18:36 2021    run_data.txt
#
#          27345037 function calls (25209487 primitive calls) in 28.006 seconds
#
#    Ordered by: internal time
#    List reduced from 10557 to 4 due to restriction <'montecarlo_numba/r_packet.py'>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.004    0.004 /home/kevin/tardis/tardis/montecarlo/montecarlo_numba/r_packet.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 /home/kevin/tardis/tardis/montecarlo/montecarlo_numba/r_packet.py:34(InteractionType)
#         1    0.000    0.000    0.000    0.000 /home/kevin/tardis/tardis/montecarlo/montecarlo_numba/r_packet.py:40(PacketStatus)
#         1    0.000    0.000    0.000    0.000 /home/kevin/tardis/tardis/montecarlo/montecarlo_numba/r_packet.py:64(RPacket)

# %%
p.sort_stats(SortKey.TIME).print_stats('single_packet_loop.py')
# Out:
# Tue May 25 09:18:36 2021    run_data.txt
#
#          27345037 function calls (25209487 primitive calls) in 28.006 seconds
#
#    Ordered by: internal time
#    List reduced from 10557 to 1 due to restriction <'single_packet_loop.py'>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.002    0.002 /home/kevin/tardis/tardis/montecarlo/montecarlo_numba/single_packet_loop.py:1(<module>)

# %%
p.sort_stats(SortKey.TIME).print_stats('montecarlo_numba/base.py')
# Out:
# Tue May 25 09:18:36 2021    run_data.txt
#
#          27345037 function calls (25209487 primitive calls) in 28.006 seconds
#
#    Ordered by: internal time
#    List reduced from 10557 to 3 due to restriction <'montecarlo_numba/base.py'>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        20   11.930    0.597   11.969    0.598 /home/kevin/tardis/tardis/montecarlo/montecarlo_numba/base.py:104(montecarlo_main_loop)
#        20    0.001    0.000   23.409    1.170 /home/kevin/tardis/tardis/montecarlo/montecarlo_numba/base.py:30(montecarlo_radial1d)
#         1    0.000    0.000    0.006    0.006 /home/kevin/tardis/tardis/montecarlo/montecarlo_numba/base.py:1(<module>)

# %%
p.sort_stats(SortKey.CALLS).print_stats(10)
# Out:
# Tue May 25 09:18:36 2021    run_data.txt
#
#          27345037 function calls (25209487 primitive calls) in 28.006 seconds
#
#    Ordered by: call count
#    List reduced from 10557 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#   4796114    0.390    0.000    0.497    0.000 {built-in method builtins.isinstance}
#   1655805    0.123    0.000    0.152    0.000 {method 'get' of 'dict' objects}
#   1035325    0.051    0.000    0.051    0.000 {built-in method builtins.id}
# 734412/1078    0.488    0.000    1.137    0.001 /home/kevin/miniconda3/envs/tardis/lib/python3.7/copy.py:132(deepcopy)
#    713092    0.052    0.000    0.052    0.000 {method 'append' of 'list' objects}
# 694266/122891    0.416    0.000    0.592    0.000 /home/kevin/miniconda3/envs/tardis/lib/python3.7/site-packages/numba/core/ir.py:313(_rec_list_vars)
# ...

# %%
# %load_ext line_profiler

# %%
from tardis.montecarlo.montecarlo_numba.r_packet import *
from tardis.montecarlo.montecarlo_numba.base import (montecarlo_radial1d, montecarlo_main_loop)
from tardis.montecarlo.montecarlo_numba import (base, r_packet)
from tardis.montecarlo.montecarlo_numba.single_packet_loop import *

# %%
#%lprun -f RPacket -f trace_packet -f run_tardis run_tardis("tardis_example.yml")

# %%
# %lprun -f base -f montecarlo_radial1d -f montecarlo_main_loop -f single_packet_loop -f run_tardis  run_tardis("tardis_example.yml")
# Out:
# [py.warnings         ][WARNING]  /home/kevin/miniconda3/envs/tardis/lib/python3.7/site-packages/line_profiler.py:321: UserWarning: Could not extract a code object for the object <module 'tardis.montecarlo.montecarlo_numba.base' from '/home/kevin/tardis/tardis/montecarlo/montecarlo_numba/base.py'>
#   profile = LineProfiler(*funcs)
#  (warnings.py:110)
# [tardis.plasma.standard_plasmas][INFO   ]  Reading Atomic Data from kurucz_cd23_chianti_H_He.h5 (standard_plasmas.py:91)
# [tardis.io.atom_data.util][INFO   ]  Atom Data kurucz_cd23_chianti_H_He.h5 not found in local path. Exists in TARDIS Data repo /home/kevin/Downloads/tardis-data/kurucz_cd23_chianti_H_He.h5 (util.py:34)
# [tardis.io.atom_data.base][INFO   ]  Read Atom Data with UUID=6f7b09e887a311e7a06b246e96350010 and MD5=864f1753714343c41f99cb065710cace. (base.py:179)
# [tardis.io.atom_data.base][INFO   ]  Non provided atomic data: synpp_refs, photoionization_data, yg_data, two_photon_data (base.py:183)
# ...

# %%
#from numba import profile
#with profile() as pp:
#    %timeit run_tardis("tardis_example.yml")

# %%
p.sort_stats(SortKey.CALLS).print_stats('/home/kevin/tardis/tardis/', 100)
# Out:
# Tue May 25 09:18:36 2021    run_data.txt
#
#          27345037 function calls (25209487 primitive calls) in 28.006 seconds
#
#    Ordered by: call count
#    List reduced from 10557 to 383 due to restriction <'/home/kevin/tardis/tardis/'>
#    List reduced from 383 to 100 due to restriction <100>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     12216    0.002    0.000    0.002    0.000 /home/kevin/tardis/tardis/plasma/properties/base.py:38(name)
#      1676    0.002    0.000    0.007    0.000 /home/kevin/tardis/tardis/io/util.py:75(match)
#      1397    0.001    0.000    0.001    0.000 /home/kevin/tardis/tardis/plasma/base.py:58(get_value)
#      1287    0.001    0.000    0.001    0.000 /home/kevin/tardis/tardis/plasma/properties/base.py:96(<genexpr>)
#       865    0.001    0.000    0.008    0.000 /home/kevin/tardis/tardis/io/util.py:36(quantity_from_str)
# ...

# %%
p.sort_stats(SortKey.CALLS).print_stats('/home/kevin/tardis/', 100)
# Out:
# Tue May 25 09:18:36 2021    run_data.txt
#
#          27345037 function calls (25209487 primitive calls) in 28.006 seconds
#
#    Ordered by: call count
#    List reduced from 10557 to 383 due to restriction <'/home/kevin/tardis/'>
#    List reduced from 383 to 100 due to restriction <100>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     12216    0.002    0.000    0.002    0.000 /home/kevin/tardis/tardis/plasma/properties/base.py:38(name)
#      1676    0.002    0.000    0.007    0.000 /home/kevin/tardis/tardis/io/util.py:75(match)
#      1397    0.001    0.000    0.001    0.000 /home/kevin/tardis/tardis/plasma/base.py:58(get_value)
#      1287    0.001    0.000    0.001    0.000 /home/kevin/tardis/tardis/plasma/properties/base.py:96(<genexpr>)
#       865    0.001    0.000    0.008    0.000 /home/kevin/tardis/tardis/io/util.py:36(quantity_from_str)
# ...
